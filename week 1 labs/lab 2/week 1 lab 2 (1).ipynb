# %%
name='Muhammad Sameer Malik'
age=22
height=5.4
is_student = False
print(name,type(name),age,type(age),height,type(height),is_student,type(is_student))
# Out:
# Muhammad Sameer Malik <class 'str'> 22 <class 'int'> 5.4 <class 'float'> False <class 'bool'>

# %%
score = int(input("Enter your score: "))

if score >= 90 and score <= 100:
    print("Grade: A")
elif score >= 80 and score <=100:
    print("Grade: B")
elif score >= 73 and score <=100:
    print("Grade: C")
elif score >= 65 and score <=100:
    print("Grade: D")
elif score >= 55 and score <=100:
    print("Grade: F")
elif score >= 0 and score <=100:
    print("Grade: F")
else:
    print("Invalid")
# Out:
# Enter your score:  390
# Invalid

# %%
n = 5
for i in range(1, n+1):
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
squares = [x**2 for x in range (1,11)]
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
sample_tuple = (1,2,3,4,5,6,7) 
sample_set = set()
sample_set.add('apple')
sample_set.add('banana')
sample_dict = {'name': 'Sameer', 'age': 22}
print("sample tuple:",sample_tuple)
print("sample set:",sample_set)
print("Dictionary:",sample_dict)
# Out:
# sample tuple: (1, 2, 3, 4, 5, 6, 7)
# sample set: {'banana', 'apple'}
# Dictionary: {'name': 'Sameer', 'age': 22}

# %%
text = "Python is simple yet powerful. Python is easy to learn."
words = text.split()
word_freq = {}
for word in words:
    if word in word_freq:
        word_freq[word] += 1
    else:
        word_freq[word] = 1
print(word_freq)
# Out:
# {'Python': 2, 'is': 2, 'simple': 1, 'yet': 1, 'powerful.': 1, 'easy': 1, 'to': 1, 'learn.': 1}

# %%
def modify_list(my_list):
    my_list.append("new item")

lst = ["item1", "item2"]
modify_list(lst)
print(lst)
# Out:
# ['item1', 'item2', 'new item']
